# %% [markdown]
# <a href="https://colab.research.google.com/github/EvgenyTsiryatyev/ET/blob/main/%D1%87%D0%B5%D1%80%D0%BD%D0%BE%D0%B2%D0%B8%D0%BA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.DataFrame({'x':[1,3,2], 'y':[2,4,1]})

# %%
df
# Out:
#    x  y
# 0  1  2
# 1  3  4
# 2  2  1

# %%
df.drop(0, axis=0, inplace=True)

# %%
df1 = pd.DataFrame({'x':[1,3,2], 'y':[2,4,1]})
df2 = pd.DataFrame({'x':[3,1,2], 'y':[0,2,2]})
print (df1>=df2)
# Out:
#        x      y
# 0  False   True
# 1   True   True
# 2   True  False

# %%
df1[df1 >1]
# Out:
#      x    y
# 0  NaN  2.0
# 1  3.0  4.0
# 2  2.0  NaN
